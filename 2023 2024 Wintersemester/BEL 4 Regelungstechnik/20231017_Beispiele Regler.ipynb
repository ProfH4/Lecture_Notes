# %% [markdown]
# ## P-Regler Beispiel

# %% [markdown]
# Ein proportionaler Regelkreis (P-Regler) ist ein grundlegendes Konzept der Regelungstechnik. Er wird oft verwendet, um ein System auf einen gewünschten Sollwert zu regeln, indem er proportional zum Fehler zwischen dem Ist- und dem Sollwert arbeitet.
#
# Hier ist ein einfacher Python-Code, der ein System mit einem P-Regler simuliert:

# %%
import matplotlib.pyplot as plt

def p_regler(kp, setpoint, initial_value, time_steps):
    time = [0]
    value = [initial_value]
    setpoint_values = [setpoint]
    error_values = [setpoint - initial_value]
    
    for i in range(1, time_steps+1):
        error = setpoint - value[-1]
        control_signal = kp * error
        value.append(value[-1] + control_signal)
        time.append(i)
        setpoint_values.append(setpoint)
        error_values.append(error)
    
    return time, value, setpoint_values, error_values

# Parameter
kp = 0.1  # Proportionalitätskonstante
setpoint = 10  # Sollwert
initial_value = 0  # Anfangswert
time_steps = 200  # Anzahl der Zeitschritte

# Simuliere den P-Regler
time, output, setpoint_values, error_values = p_regler(kp, setpoint, initial_value, time_steps)

# Plot Eingang (Sollwert und Fehler)
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(time, setpoint_values, label='Sollwert', color='red')
plt.plot(time, error_values, label='Fehler', color='blue')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Eingang des P-Reglers')
plt.legend()

# Plot Ausgang
plt.subplot(1, 2, 2)
plt.plot(time, output, label='Ausgang', color='green')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Ausgang des P-Reglers')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def p_regler(kp, setpoint_func, initial_value, time_steps):
    time = [0]
    value = [initial_value]
    setpoint_values = [setpoint_func(0)]
    error_values = [setpoint_func(0) - initial_value]
    
    for i in range(1, time_steps+1):
        setpoint = setpoint_func(i)
        error = setpoint - value[-1]
        control_signal = kp * error
        value.append(value[-1] + control_signal)
        time.append(i)
        setpoint_values.append(setpoint)
        error_values.append(error)
    
    return time, value, setpoint_values, error_values

# Define the sinusoidal setpoint function
def sinusoidal_setpoint(t):
    return 5 * np.sin(0.2 * t)

# Parameter
kp = 0.1  # Proportionalitätskonstante
initial_value = 0  # Anfangswert
time_steps = 200  # Anzahl der Zeitschritte

# Simuliere den P-Regler
time, output, setpoint_values, error_values = p_regler(kp, sinusoidal_setpoint, initial_value, time_steps)

# Plot Eingang (Sollwert und Fehler)
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(time, setpoint_values, label='Sollwert', color='red')
plt.plot(time, error_values, label='Fehler', color='blue')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Eingang des P-Reglers')
plt.legend()

# Plot Ausgang
plt.subplot(1, 2, 2)
plt.plot(time, output, label='Ausgang', color='green')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Ausgang des P-Reglers')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## I-Regler Beispiel

# %% [markdown]
# Ein Integralregler (I-Regler) ist ein weiteres grundlegendes Konzept in der Regelungstechnik. Er reagiert proportional zur kumulierten Fehlerüberzeit, was dazu beitragen kann, den stationären Fehler zu eliminieren.
#
# Hier ist ein einfacher Python-Code, der ein System mit einem I-Regler simuliert:

# %%
import matplotlib.pyplot as plt

def i_regler(ki, setpoint, initial_value, time_steps):
    time = [0]
    value = [initial_value]
    setpoint_values = [setpoint]
    error_values = [setpoint - initial_value]
    integral = 0
    
    for i in range(1, time_steps+1):
        error = setpoint - value[-1]
        integral += error
        control_signal = ki * integral
        value.append(value[-1] + control_signal)
        time.append(i)
        setpoint_values.append(setpoint)
        error_values.append(error)
    
    return time, value, setpoint_values, error_values

# Parameter
ki = 0.01  # Integrationskonstante
setpoint = 10  # Sollwert
initial_value = 0  # Anfangswert
time_steps = 200  # Anzahl der Zeitschritte

# Simuliere den I-Regler
time, output, setpoint_values, error_values = i_regler(ki, setpoint, initial_value, time_steps)

# Plot Eingang (Sollwert und Fehler)
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(time, setpoint_values, label='Sollwert', color='red')
plt.plot(time, error_values, label='Fehler', color='blue')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Eingang des I-Reglers')
plt.legend()

# Plot Ausgang
plt.subplot(1, 2, 2)
plt.plot(time, output, label='Ausgang', color='green')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Ausgang des I-Reglers')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def i_regler(ki, setpoint_func, initial_value, time_steps):
    time = [0]
    value = [initial_value]
    setpoint_values = [setpoint_func(0)]
    error_values = [setpoint_func(0) - initial_value]
    integral = 0
    
    for i in range(1, time_steps+1):
        setpoint = setpoint_func(i)
        error = setpoint - value[-1]
        integral += error
        control_signal = ki * integral
        value.append(value[-1] + control_signal)
        time.append(i)
        setpoint_values.append(setpoint)
        error_values.append(error)
    
    return time, value, setpoint_values, error_values

# Define the sinusoidal setpoint function
def sinusoidal_setpoint(t):
    return 5 * np.sin(0.2 * t)

# Parameter
ki = 0.01  # Integrationskonstante
initial_value = 0  # Anfangswert
time_steps = 200  # Anzahl der Zeitschritte

# Simuliere den I-Regler
time, output, setpoint_values, error_values = i_regler(ki, sinusoidal_setpoint, initial_value, time_steps)

# Plot Eingang (Sollwert und Fehler)
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(time, setpoint_values, label='Sollwert', color='red')
plt.plot(time, error_values, label='Fehler', color='blue')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Eingang des I-Reglers')
plt.legend()

# Plot Ausgang
plt.subplot(1, 2, 2)
plt.plot(time, output, label='Ausgang', color='green')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Ausgang des I-Reglers')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # D-Regler Beispiel

# %% [markdown]
# Ein Differentialregler (D-Regler) reagiert proportional zur zeitlichen Änderung des Fehlers. Es ist wichtig zu beachten, dass ein reiner D-Regler oft instabil ist, daher wird er in der Praxis oft mit einem P- oder PI-Regler kombiniert, um ein PD- oder PID-Regler zu erhalten.
#
# Hier ist ein einfacher Python-Code, der ein System mit einem D-Regler simuliert:

# %%
import matplotlib.pyplot as plt

def d_regler(control_signal_func, setpoint_func, initial_value, time_steps):
    time = [0]
    value = [initial_value]
    setpoint_values = [setpoint_func(0)]
    error_values = [setpoint_func(0) - initial_value]
    
    for i in range(1, time_steps+1):
        error = setpoint_func(i-1) - value[-1]
        control_signal = control_signal_func(i-1, error)
        value.append(value[-1] + control_signal)
        time.append(i)
        setpoint_values.append(setpoint_func(i))
        error_values.append(error)
    
    return time, value, setpoint_values, error_values

# Define time-varying control signal and setpoint functions
def control_signal_func(t, error):
    return 0.1 * t * error  # Example: Control signal varies with time

def setpoint_func(t):
    return 10 + 0.2 * t  # Example: Setpoint increases linearly with time

# Parameter
initial_value = 0  # Anfangswert
time_steps = 50  # Anzahl der Zeitschritte

# Simuliere den D-Regler
time, output, setpoint_values, error_values = d_regler(control_signal_func, setpoint_func, initial_value, time_steps)

# Plot Eingang (Sollwert und Fehler)
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(time, setpoint_values, label='Sollwert', color='red')
plt.plot(time, error_values, label='Fehler', color='blue')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Eingang des D-Reglers')
plt.legend()

# Plot Ausgang
plt.subplot(1, 2, 2)
plt.plot(time, output, label='Ausgang', color='green')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Ausgang des D-Reglers')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def d_regler(control_signal_func, setpoint_func, initial_value, time_steps):
    time = [0]
    value = [initial_value]
    setpoint_values = [setpoint_func(0)]
    error_values = [setpoint_func(0) - initial_value]
    
    for i in range(1, time_steps+1):
        error = setpoint_func(i-1) - value[-1]
        control_signal = control_signal_func(i-1, error)
        value.append(value[-1] + control_signal)
        time.append(i)
        setpoint_values.append(setpoint_func(i))
        error_values.append(error)
    
    return time, value, setpoint_values, error_values

# Define time-varying control signal and setpoint functions with sinusoidal behavior
def control_signal_func(t, error):
    return 0.1 * np.sin(0.2 * t) * error  # Example: Control signal varies sinusoidally with time

def setpoint_func(t):
    return 10 + 5 * np.sin(0.1 * t)  # Example: Setpoint varies sinusoidally with time

# Parameter
initial_value = 0  # Anfangswert
time_steps = 200  # Anzahl der Zeitschritte

# Simuliere den D-Regler
time, output, setpoint_values, error_values = d_regler(control_signal_func, setpoint_func, initial_value, time_steps)

# Plot Eingang (Sollwert und Fehler)
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(time, setpoint_values, label='Sollwert', color='red')
plt.plot(time, error_values, label='Fehler', color='blue')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Eingang des D-Reglers')
plt.legend()

# Plot Ausgang
plt.subplot(1, 2, 2)
plt.plot(time, output, label='Ausgang', color='green')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Ausgang des D-Reglers')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # PI Regler Beispiel

# %% [markdown]
# Ein PI-Regler ist ein Regler, der sowohl proportional als auch integral auf den Fehler reagiert. Dies hilft, den stationären Fehler zu eliminieren und das Systemverhalten zu verbessern.
#
# Hier ist ein Python-Code, um ein System mit einem PI-Regler zu simulieren:

# %%
import matplotlib.pyplot as plt

def pi_regler(kp, ki, setpoint, initial_value, time_steps):
    time = [0]
    value = [initial_value]
    setpoint_values = [setpoint]
    error_values = [setpoint - initial_value]
    integral = 0
    
    for i in range(1, time_steps+1):
        error = setpoint - value[-1]
        integral += error
        control_signal = kp * error + ki * integral
        value.append(value[-1] + control_signal)
        time.append(i)
        setpoint_values.append(setpoint)
        error_values.append(error)
    
    return time, value, setpoint_values, error_values

# Parameter
kp = 0.1  # Proportionalitätskonstante
ki = 0.01  # Integrationskonstante
setpoint = 10  # Sollwert
initial_value = 0  # Anfangswert
time_steps = 200  # Anzahl der Zeitschritte

# Simuliere den PI-Regler
time, output, setpoint_values, error_values = pi_regler(kp, ki, setpoint, initial_value, time_steps)

# Plot Eingang (Sollwert und Fehler)
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(time, setpoint_values, label='Sollwert', color='red')
plt.plot(time, error_values, label='Fehler', color='blue')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Eingang des PI-Reglers')
plt.legend()

# Plot Ausgang
plt.subplot(1, 2, 2)
plt.plot(time, output, label='Ausgang', color='green')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Ausgang des PI-Reglers')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def pi_regler(kp, ki, setpoint_func, initial_value, time_steps):
    time = [0]
    value = [initial_value]
    setpoint_values = [setpoint_func(0)]
    error_values = [setpoint_func(0) - initial_value]
    integral = 0
    
    for i in range(1, time_steps+1):
        setpoint = setpoint_func(i)
        error = setpoint - value[-1]
        integral += error
        control_signal = kp * error + ki * integral
        value.append(value[-1] + control_signal)
        time.append(i)
        setpoint_values.append(setpoint)
        error_values.append(error)
    
    return time, value, setpoint_values, error_values

# Define time-varying control signal and setpoint functions with sinusoidal behavior
def control_signal_func(t, error):
    return 0.1 * np.sin(0.2 * t) * error  # Example: Control signal varies sinusoidally with time

def setpoint_func(t):
    return 10 + 5 * np.sin(0.1 * t)  # Example: Setpoint varies sinusoidally with time

# Parameter
kp = 0.1  # Proportionalitätskonstante
ki = 0.01  # Integrationskonstante
initial_value = 0  # Anfangswert
time_steps = 200  # Anzahl der Zeitschritte

# Simuliere den PI-Regler
time, output, setpoint_values, error_values = pi_regler(kp, ki, setpoint_func, initial_value, time_steps)

# Plot Eingang (Sollwert und Fehler)
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(time, setpoint_values, label='Sollwert', color='red')
plt.plot(time, error_values, label='Fehler', color='blue')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Eingang des PI-Reglers')
plt.legend()

# Plot Ausgang
plt.subplot(1, 2, 2)
plt.plot(time, output, label='Ausgang', color='green')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Ausgang des PI-Reglers')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # PD Regler Beispiel

# %% [markdown]
# Ein PD-Regler reagiert proportional zur zeitlichen Änderung des Fehlers.
#
# Hier ist ein Python-Code, um ein System mit einem PD-Regler zu simulieren:

# %%
import matplotlib.pyplot as plt

def pd_regler(kp, kd, setpoint, initial_value, time_steps):
    time = [0]
    value = [initial_value]
    setpoint_values = [setpoint]
    error_values = [setpoint - initial_value]
    prev_error = error_values[-1]
    
    for i in range(1, time_steps+1):
        error = setpoint - value[-1]
        control_signal = kp * error + kd * (error - prev_error)
        value.append(value[-1] + control_signal)
        time.append(i)
        setpoint_values.append(setpoint)
        error_values.append(error)
        prev_error = error
    
    return time, value, setpoint_values, error_values

# Parameter
kp = 0.1  # Proportionalitätskonstante
kd = 0.01  # Differentialkonstante
setpoint = 10  # Sollwert
initial_value = 0  # Anfangswert
time_steps = 200  # Anzahl der Zeitschritte

# Simuliere den PD-Regler
time, output, setpoint_values, error_values = pd_regler(kp, kd, setpoint, initial_value, time_steps)

# Plot Eingang (Sollwert und Fehler)
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(time, setpoint_values, label='Sollwert', color='red')
plt.plot(time, error_values, label='Fehler', color='blue')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Eingang des PD-Reglers')
plt.legend()

# Plot Ausgang
plt.subplot(1, 2, 2)
plt.plot(time, output, label='Ausgang', color='green')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Ausgang des PD-Reglers')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def pd_regler(kp, kd, setpoint_func, initial_value, time_steps):
    time = [0]
    value = [initial_value]
    setpoint_values = [setpoint_func(0)]
    error_values = [setpoint_func(0) - initial_value]
    prev_error = error_values[-1]
    
    for i in range(1, time_steps+1):
        setpoint = setpoint_func(i)
        error = setpoint - value[-1]
        control_signal = kp * error + kd * (error - prev_error)
        value.append(value[-1] + control_signal)
        time.append(i)
        setpoint_values.append(setpoint)
        error_values.append(error)
        prev_error = error
    
    return time, value, setpoint_values, error_values

# Define time-varying control signal and setpoint functions with sinusoidal behavior
def control_signal_func(t, error):
    return 0.1 * np.sin(0.2 * t) * error  # Example: Control signal varies sinusoidally with time

def setpoint_func(t):
    return 10 + 5 * np.sin(0.1 * t)  # Example: Setpoint varies sinusoidally with time

# Parameter
kp = 0.1  # Proportionalitätskonstante
kd = 0.01  # Differentialkonstante
initial_value = 0  # Anfangswert
time_steps = 200  # Anzahl der Zeitschritte

# Simuliere den PD-Regler
time, output, setpoint_values, error_values = pd_regler(kp, kd, setpoint_func, initial_value, time_steps)

# Plot Eingang (Sollwert und Fehler)
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(time, setpoint_values, label='Sollwert', color='red')
plt.plot(time, error_values, label='Fehler', color='blue')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Eingang des PD-Reglers')
plt.legend()

# Plot Ausgang
plt.subplot(1, 2, 2)
plt.plot(time, output, label='Ausgang', color='green')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Ausgang des PD-Reglers')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # PID Regler Beispiel

# %% [markdown]
# Ein PID-Regler kombiniert proportional, integral und differential Aktionen, um eine genauere Regelung zu ermöglichen.
#
# Hier ist der Python-Code für ein System mit einem PID-Regler:

# %%
import matplotlib.pyplot as plt

def pid_regler(kp, ki, kd, setpoint, initial_value, time_steps):
    time = [0]
    value = [initial_value]
    setpoint_values = [setpoint]
    error_values = [setpoint - initial_value]
    integral = 0
    prev_error = error_values[-1]
    
    for i in range(1, time_steps+1):
        error = setpoint - value[-1]
        integral += error
        derivative = error - prev_error
        control_signal = kp * error + ki * integral + kd * derivative
        value.append(value[-1] + control_signal)
        time.append(i)
        setpoint_values.append(setpoint)
        error_values.append(error)
        prev_error = error
    
    return time, value, setpoint_values, error_values

# Parameter
kp = 0.1  # Proportionalitätskonstante
ki = 0.01  # Integrationskonstante
kd = 0.01  # Differentialkonstante
setpoint = 10  # Sollwert
initial_value = 0  # Anfangswert
time_steps = 200  # Anzahl der Zeitschritte

# Simuliere den PID-Regler
time, output, setpoint_values, error_values = pid_regler(kp, ki, kd, setpoint, initial_value, time_steps)

# Plot Eingang (Sollwert und Fehler)
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(time, setpoint_values, label='Sollwert', color='red')
plt.plot(time, error_values, label='Fehler', color='blue')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Eingang des PID-Reglers')
plt.legend()

# Plot Ausgang
plt.subplot(1, 2, 2)
plt.plot(time, output, label='Ausgang', color='green')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Ausgang des PID-Reglers')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

def pid_regler(kp, ki, kd, setpoint_func, initial_value, time_steps):
    time = [0]
    value = [initial_value]
    setpoint_values = [setpoint_func(0)]
    error_values = [setpoint_func(0) - initial_value]
    integral = 0
    prev_error = error_values[-1]
    
    for i in range(1, time_steps+1):
        setpoint = setpoint_func(i)
        error = setpoint - value[-1]
        integral += error
        derivative = error - prev_error
        control_signal = kp * error + ki * integral + kd * derivative
        value.append(value[-1] + control_signal)
        time.append(i)
        setpoint_values.append(setpoint)
        error_values.append(error)
        prev_error = error
    
    return time, value, setpoint_values, error_values

# Define time-varying control signal and setpoint functions with sinusoidal behavior
def control_signal_func(t, error):
    return 0.1 * np.sin(0.2 * t) * error  # Example: Control signal varies sinusoidally with time

def setpoint_func(t):
    return 10 + 5 * np.sin(0.1 * t)  # Example: Setpoint varies sinusoidally with time

# Parameter
kp = 0.1  # Proportionalitätskonstante
ki = 0.01  # Integrationskonstante
kd = 0.01  # Differentialkonstante
initial_value = 0  # Anfangswert
time_steps = 200  # Anzahl der Zeitschritte

# Simuliere den PID-Regler
time, output, setpoint_values, error_values = pid_regler(kp, ki, kd, setpoint_func, initial_value, time_steps)

# Plot Eingang (Sollwert und Fehler)
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(time, setpoint_values, label='Sollwert', color='red')
plt.plot(time, error_values, label='Fehler', color='blue')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Eingang des PID-Reglers')
plt.legend()

# Plot Ausgang
plt.subplot(1, 2, 2)
plt.plot(time, output, label='Ausgang', color='green')
plt.xlabel('Zeitschritte')
plt.ylabel('Wert')
plt.title('Ausgang des PID-Reglers')
plt.legend()

plt.tight_layout()
plt.show()
